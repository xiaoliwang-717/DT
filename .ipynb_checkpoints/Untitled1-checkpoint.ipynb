# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)
import numpy as np
import matplotlib.pyplot as plt

# %%
# translate all data to .csv
# def xlsx_to_csv_pd():
#     data_xls = pd.read_excel("C:/Users/xiaol/PycharmProjects/zzw/Data/data.xlsx", index_col=0)
#     data_xls.to_csv('C:/Users/xiaol/PycharmProjects/zzw/Data/data.csv', encoding='utf-8')
# xlsx_to_csv_pd()

# %%
# load all data
df = pd.read_csv("data.csv")

# %%
# remove some features
# 'Adensity','AC_material_weight','TD_weight','Measure_Velocity','Overpressure'
df = df.drop(columns=['Overpressure'])

# %%
# normalize function
def normalize(column):
    return ((column - column.mean()) / column.std())

data_norm = df.iloc[:,:-1].apply(normalize)
data_norm
# Out:
#           Ti        Zr         W      PTFE  Tdensity  Adensity  MS_Velocity  \
# 0   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 1   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 2   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 3   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 4   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# ..       ...       ...       ...       ...       ...       ...          ...
# 60 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 61 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 62 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 63 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 64 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
#
#     RL_Constant  GibbThom_Coef  Coeff_Thermal_Exp  SHC_Const_Press     CEP_Q  \
# 0      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 1      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 2      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 3      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 4      1.833980      -0.629327           1.142312         1.632251 -0.987225
# ..          ...            ...                ...              ...       ...
# 60    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 61    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 62    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 63    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 64    -1.279305       1.809805          -2.102486        -1.569019  2.148866
#
#        CEP_q  AC_material_weight  TD_weight  Measure_Velocity  \
# 0   1.862233           -1.052239  -0.981612         -0.846701
# 1   1.862233           -1.052239  -0.995733         -0.217632
# 2   1.862233           -1.030599  -0.995733          0.148661
# 3   1.862233           -1.052239  -0.946310          0.347734
# 4   1.862233           -1.059452  -0.939250          0.980784
# ..       ...                 ...        ...               ...
# 60 -1.219114            2.020583   2.075540         -1.304568
# 61 -1.219114            2.006156   2.499163         -0.619759
# 62 -1.219114            2.027796   2.026117          0.096902
# 63 -1.219114            1.998943   2.061419          1.052450
# 64 -1.219114            1.998943   2.061419          1.319207
#
#     Residual_Velocity  Impact_Pressure  Impact_Temp_Rise
# 0           -0.884794        -1.235362         -1.083532
# 1           -0.247321        -0.961208         -0.591027
# 2            0.124603        -0.792617         -0.261894
# 3            0.297661        -0.711995         -0.097625
# 4            0.936319        -0.402653          0.572750
# ..                ...              ...               ...
# 60          -1.229155         0.093647         -1.071719
# 61          -0.526387         0.798367         -0.461066
# 62           0.183323         1.545814          0.301684
# 63           1.149068         2.620970          1.588875
# 64           1.418170         2.932825          2.001172
#
# [65 rows x 19 columns]

# %%
data_norm['React_Efficiency'] = df['React_Efficiency']
data_norm
# Out:
#           Ti        Zr         W      PTFE  Tdensity  Adensity  MS_Velocity  \
# 0   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 1   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 2   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 3   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# 4   1.699682 -0.827985 -1.210879  1.594698 -1.040969 -1.041154    -1.263353
# ..       ...       ...       ...       ...       ...       ...          ...
# 60 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 61 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 62 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 63 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
# 64 -0.893730 -0.188822  1.528348 -1.576793  2.083968  2.131193     1.540791
#
#     RL_Constant  GibbThom_Coef  Coeff_Thermal_Exp  SHC_Const_Press     CEP_Q  \
# 0      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 1      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 2      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 3      1.833980      -0.629327           1.142312         1.632251 -0.987225
# 4      1.833980      -0.629327           1.142312         1.632251 -0.987225
# ..          ...            ...                ...              ...       ...
# 60    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 61    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 62    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 63    -1.279305       1.809805          -2.102486        -1.569019  2.148866
# 64    -1.279305       1.809805          -2.102486        -1.569019  2.148866
#
#        CEP_q  AC_material_weight  TD_weight  Measure_Velocity  \
# 0   1.862233           -1.052239  -0.981612         -0.846701
# 1   1.862233           -1.052239  -0.995733         -0.217632
# 2   1.862233           -1.030599  -0.995733          0.148661
# 3   1.862233           -1.052239  -0.946310          0.347734
# 4   1.862233           -1.059452  -0.939250          0.980784
# ..       ...                 ...        ...               ...
# 60 -1.219114            2.020583   2.075540         -1.304568
# 61 -1.219114            2.006156   2.499163         -0.619759
# 62 -1.219114            2.027796   2.026117          0.096902
# 63 -1.219114            1.998943   2.061419          1.052450
# 64 -1.219114            1.998943   2.061419          1.319207
#
#     Residual_Velocity  Impact_Pressure  Impact_Temp_Rise  React_Efficiency
# 0           -0.884794        -1.235362         -1.083532             0.866
# 1           -0.247321        -0.961208         -0.591027             2.759
# 2            0.124603        -0.792617         -0.261894             5.860
# 3            0.297661        -0.711995         -0.097625             8.657
# 4            0.936319        -0.402653          0.572750            29.103
# ..                ...              ...               ...               ...
# 60          -1.229155         0.093647         -1.071719             9.756
# 61          -0.526387         0.798367         -0.461066            13.638
# 62           0.183323         1.545814          0.301684            28.117
# 63           1.149068         2.620970          1.588875            43.008
# 64           1.418170         2.932825          2.001172            70.396
#
# [65 rows x 20 columns]

# %%
# heatmap
plt.figure(figsize=(16, 5))
c = data_norm.corr()
sns.heatmap(c, cmap="BrBG", annot=True)
c
# Out:
#                           Ti        Zr         W      PTFE  Tdensity  \
# Ti                  1.000000 -0.751557 -0.334694  0.625477 -0.485956
# Zr                 -0.751557  1.000000 -0.370081  0.044618 -0.177556
# W                  -0.334694 -0.370081  1.000000 -0.944587  0.938000
# PTFE                0.625477  0.044618 -0.944587  1.000000 -0.945943
# Tdensity           -0.485956 -0.177556  0.938000 -0.945943  1.000000
# Adensity           -0.481499 -0.181349  0.937142 -0.943680  0.999604
# MS_Velocity        -0.370915 -0.333847  0.999250 -0.956584  0.944179
# RL_Constant         0.941345 -0.484880 -0.633036  0.852071 -0.734713
# GibbThom_Coef      -0.164454 -0.492143  0.934618 -0.831149  0.934334
# Coeff_Thermal_Exp   0.583980  0.060122 -0.908292  0.955492 -0.992558
# SHC_Const_Press     0.656340  0.004418 -0.930625  0.999191 -0.939525
# CEP_Q              -0.485720 -0.170300  0.927302 -0.937002  0.999197
# CEP_q               0.947255 -0.501057 -0.618251  0.841887 -0.717263
# AC_material_weight -0.469699 -0.196291  0.941868 -0.943482  0.997872
# TD_weight          -0.440436 -0.217249  0.930593 -0.923951  0.990204
# Measure_Velocity    0.091564 -0.045481 -0.063972  0.084861 -0.086943
# Residual_Velocity   0.070397 -0.056880 -0.017882  0.039325 -0.039130
# Impact_Pressure    -0.298536 -0.188747  0.690050 -0.675356  0.689368
# Impact_Temp_Rise   -0.084724 -0.006849  0.129102 -0.136412  0.117556
# React_Efficiency   -0.156313 -0.003736  0.225465 -0.241132  0.207007
#
#                     Adensity  MS_Velocity  RL_Constant  GibbThom_Coef  \
# Ti                 -0.481499    -0.370915     0.941345      -0.164454
# Zr                 -0.181349    -0.333847    -0.484880      -0.492143
# W                   0.937142     0.999250    -0.633036       0.934618
# PTFE               -0.943680    -0.956584     0.852071      -0.831149
# Tdensity            0.999604     0.944179    -0.734713       0.934334
# Adensity            1.000000     0.943133    -0.730747       0.934126
# MS_Velocity         0.943133     1.000000    -0.662523       0.927662
# RL_Constant        -0.730747    -0.662523     1.000000      -0.469572
# GibbThom_Coef       0.934126     0.927662    -0.469572       1.000000
# Coeff_Thermal_Exp  -0.991961    -0.918926     0.804556      -0.884525
# SHC_Const_Press    -0.937091    -0.944092     0.872426      -0.812000
# CEP_Q               0.999123     0.933605    -0.730612       0.929180
# CEP_q              -0.713129    -0.648207     0.999601      -0.449307
# AC_material_weight  0.997005     0.947344    -0.722758       0.941018
# TD_weight           0.990249     0.934985    -0.694703       0.939886
# Measure_Velocity   -0.086712    -0.066765     0.098232      -0.064809
# Residual_Velocity  -0.039113    -0.020475     0.064361      -0.019113
# Impact_Pressure     0.688701     0.692262    -0.492105       0.660549
# Impact_Temp_Rise    0.116772     0.130745    -0.115684       0.095180
# React_Efficiency    0.206879     0.228613    -0.209333       0.174716
#
#                     Coeff_Thermal_Exp  SHC_Const_Press     CEP_Q     CEP_q  \
# Ti                           0.583980         0.656340 -0.485720  0.947255
# Zr                           0.060122         0.004418 -0.170300 -0.501057
# W                           -0.908292        -0.930625  0.927302 -0.618251
# PTFE                         0.955492         0.999191 -0.937002  0.841887
# Tdensity                    -0.992558        -0.939525  0.999197 -0.717263
# Adensity                    -0.991961        -0.937091  0.999123 -0.713129
# MS_Velocity                 -0.918926        -0.944092  0.933605 -0.648207
# RL_Constant                  0.804556         0.872426 -0.730612  0.999601
# GibbThom_Coef               -0.884525        -0.812000  0.929180 -0.449307
# Coeff_Thermal_Exp            1.000000         0.953794 -0.993131  0.788644
# SHC_Const_Press              0.953794         1.000000 -0.930839  0.862902
# CEP_Q                       -0.993131        -0.930839  1.000000 -0.712593
# CEP_q                        0.788644         0.862902 -0.712593  1.000000
# AC_material_weight          -0.987827        -0.936327  0.996267 -0.705290
# TD_weight                   -0.977554        -0.915914  0.989886 -0.676530
# Measure_Velocity             0.092682         0.086830 -0.087201  0.097551
# Residual_Velocity            0.045578         0.041714 -0.039528  0.064522
# Impact_Pressure             -0.677448        -0.668312  0.685488 -0.480645
# Impact_Temp_Rise            -0.120294        -0.136216  0.116594 -0.114535
# React_Efficiency            -0.210105        -0.241224  0.203297 -0.208338
#
#                     AC_material_weight  TD_weight  Measure_Velocity  \
# Ti                           -0.469699  -0.440436          0.091564
# Zr                           -0.196291  -0.217249         -0.045481
# W                             0.941868   0.930593         -0.063972
# PTFE                         -0.943482  -0.923951          0.084861
# Tdensity                      0.997872   0.990204         -0.086943
# Adensity                      0.997005   0.990249         -0.086712
# MS_Velocity                   0.947344   0.934985         -0.066765
# RL_Constant                  -0.722758  -0.694703          0.098232
# GibbThom_Coef                 0.941018   0.939886         -0.064809
# Coeff_Thermal_Exp            -0.987827  -0.977554          0.092682
# SHC_Const_Press              -0.936327  -0.915914          0.086830
# CEP_Q                         0.996267   0.989886         -0.087201
# CEP_q                        -0.705290  -0.676530          0.097551
# AC_material_weight            1.000000   0.990597         -0.080213
# TD_weight                     0.990597   1.000000         -0.069564
# Measure_Velocity             -0.080213  -0.069564          1.000000
# Residual_Velocity            -0.032133  -0.021301          0.998674
# Impact_Pressure               0.695426   0.693607          0.625319
# Impact_Temp_Rise              0.121262   0.129475          0.963935
# React_Efficiency              0.209725   0.219447          0.838255
#
#                     Residual_Velocity  Impact_Pressure  Impact_Temp_Rise  \
# Ti                           0.070397        -0.298536         -0.084724
# Zr                          -0.056880        -0.188747         -0.006849
# W                           -0.017882         0.690050          0.129102
# PTFE                         0.039325        -0.675356         -0.136412
# Tdensity                    -0.039130         0.689368          0.117556
# Adensity                    -0.039113         0.688701          0.116772
# MS_Velocity                 -0.020475         0.692262          0.130745
# RL_Constant                  0.064361        -0.492105         -0.115684
# GibbThom_Coef               -0.019113         0.660549          0.095180
# Coeff_Thermal_Exp            0.045578        -0.677448         -0.120294
# SHC_Const_Press              0.041714        -0.668312         -0.136216
# CEP_Q                       -0.039528         0.685488          0.116594
# CEP_q                        0.064522        -0.480645         -0.114535
# AC_material_weight          -0.032133         0.695426          0.121262
# TD_weight                   -0.021301         0.693607          0.129475
# Measure_Velocity             0.998674         0.625319          0.963935
# Residual_Velocity            1.000000         0.661436          0.972562
# Impact_Pressure              0.661436         1.000000          0.773053
# Impact_Temp_Rise             0.972562         0.773053          1.000000
# React_Efficiency             0.850468         0.764140          0.919595
#
#                     React_Efficiency
# Ti                         -0.156313
# Zr                         -0.003736
# W                           0.225465
# PTFE                       -0.241132
# Tdensity                    0.207007
# Adensity                    0.206879
# MS_Velocity                 0.228613
# RL_Constant                -0.209333
# GibbThom_Coef               0.174716
# Coeff_Thermal_Exp          -0.210105
# SHC_Const_Press            -0.241224
# CEP_Q                       0.203297
# CEP_q                      -0.208338
# AC_material_weight          0.209725
# TD_weight                   0.219447
# Measure_Velocity            0.838255
# Residual_Velocity           0.850468
# Impact_Pressure             0.764140
# Impact_Temp_Rise            0.919595
# React_Efficiency            1.000000

# %%
# construct train_data and test_data 
# way 1 : select 4 group Zr&Ti as train data

test_data = pd.concat([data_norm.iloc[27:34], data_norm.iloc[59:65]])
select_test_indices = list(range(27, 34)) + list(range(59, 65))
train_data = data_norm.drop(select_test_indices)

X_train = train_data.drop(columns=['React_Efficiency'])
y_train = train_data['React_Efficiency']
X_test = test_data.drop(columns=['React_Efficiency'])
y_test = test_data['React_Efficiency']

# %%
# way2: random split train & test data
# from sklearn.model_selection import train_test_split
# X = data_norm.drop('React_Efficiency', axis=1)
# y = data_norm['React_Efficiency']
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

mse = sum((y_pred - y_test)**2)
print('mse:', mse)
print('y_test:', y_test)
print('y_pred:', y_pred)
# Out:
# mse: 35005.91672746772
# y_test: 27     1.004
# 28     9.060
# 29    12.840
# 30    23.340
# 31    35.028
# 32    37.779
# 33    51.370
# 59     7.055
# 60     9.756
# 61    13.638
# 62    28.117
# 63    43.008
# 64    70.396
# Name: React_Efficiency, dtype: float64
# y_pred: [ 51.55589464  42.99633407  52.95047569  50.71968281  54.03495507
#   60.96984618  67.27240659 -46.36181518 -50.60299835 -56.14482327
#  -43.05404503 -22.21950784 -13.87814617]

# %%
# MLP
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import numpy as np

# %%
X = X_train.values
y = y_train.values
X_train = torch.tensor(X, dtype=torch.float32)
y_train = torch.tensor(y, dtype=torch.float32).view(-1, 1)

# %%
X_test, y_test = X_test.values, y_test.values
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
class Net(nn.Module):
    def __init__(self, input_dim):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, 1)  # 输出层，输出一个值，因为是回归任务

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x
    
# 初始化模型
input_dim = X_train.shape[1]
model = Net(input_dim)

# 定义损失函数和优化器
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.005)

# 训练模型
num_epochs = 70
for epoch in range(num_epochs):
    model.train()
    optimizer.zero_grad()
    outputs = model(X_train)
    loss = criterion(outputs, y_train)
    loss.backward()
    optimizer.step()
    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')

# 评估模型
model.eval()
with torch.no_grad():
    y_pred = model(X_test)
    mse = criterion(y_pred, y_test)
    mse_sum = torch.sum((y_pred - y_test)**2)
    print(mse_sum.item())
    print("Mean Squared Error:", mse.item())
# Out:
# Epoch [1/70], Loss: 714.6325
# Epoch [2/70], Loss: 707.5032
# Epoch [3/70], Loss: 700.0507
# Epoch [4/70], Loss: 691.3901
# Epoch [5/70], Loss: 681.0612
# Epoch [6/70], Loss: 668.5351
# Epoch [7/70], Loss: 653.6448
# Epoch [8/70], Loss: 636.1802
# Epoch [9/70], Loss: 616.0560
# Epoch [10/70], Loss: 593.1609
# Epoch [11/70], Loss: 567.5411
# Epoch [12/70], Loss: 539.3599
# Epoch [13/70], Loss: 508.9336
# Epoch [14/70], Loss: 476.8178
# Epoch [15/70], Loss: 443.9425
# Epoch [16/70], Loss: 411.2990
# Epoch [17/70], Loss: 380.0303
# Epoch [18/70], Loss: 351.2185
# Epoch [19/70], Loss: 325.4725
# Epoch [20/70], Loss: 302.5513
# Epoch [21/70], Loss: 281.3730
# Epoch [22/70], Loss: 260.3924
# Epoch [23/70], Loss: 238.3595
# Epoch [24/70], Loss: 214.8622
# Epoch [25/70], Loss: 190.2219
# Epoch [26/70], Loss: 165.7051
# Epoch [27/70], Loss: 142.4535
# Epoch [28/70], Loss: 121.7443
# Epoch [29/70], Loss: 104.5565
# Epoch [30/70], Loss: 91.7188
# Epoch [31/70], Loss: 83.0409
# Epoch [32/70], Loss: 77.7822
# Epoch [33/70], Loss: 74.9656
# Epoch [34/70], Loss: 73.3926
# Epoch [35/70], Loss: 71.8470
# Epoch [36/70], Loss: 69.6177
# Epoch [37/70], Loss: 66.4114
# Epoch [38/70], Loss: 62.2547
# Epoch [39/70], Loss: 57.5290
# Epoch [40/70], Loss: 52.6362
# Epoch [41/70], Loss: 48.1004
# Epoch [42/70], Loss: 44.3202
# Epoch [43/70], Loss: 41.4492
# Epoch [44/70], Loss: 39.5757
# Epoch [45/70], Loss: 38.6122
# Epoch [46/70], Loss: 38.3878
# Epoch [47/70], Loss: 38.5856
# Epoch [48/70], Loss: 38.8964
# Epoch [49/70], Loss: 39.0356
# Epoch [50/70], Loss: 38.8711
# Epoch [51/70], Loss: 38.3528
# Epoch [52/70], Loss: 37.5542
# Epoch [53/70], Loss: 36.5390
# Epoch [54/70], Loss: 35.4153
# Epoch [55/70], Loss: 34.2718
# Epoch [56/70], Loss: 33.1804
# Epoch [57/70], Loss: 32.1914
# Epoch [58/70], Loss: 31.3533
# Epoch [59/70], Loss: 30.7021
# Epoch [60/70], Loss: 30.2418
# Epoch [61/70], Loss: 29.9611
# Epoch [62/70], Loss: 29.8199
# Epoch [63/70], Loss: 29.7622
# Epoch [64/70], Loss: 29.7284
# Epoch [65/70], Loss: 29.6533
# Epoch [66/70], Loss: 29.5332
# Epoch [67/70], Loss: 29.3604
# Epoch [68/70], Loss: 29.1467
# Epoch [69/70], Loss: 28.8989
# Epoch [70/70], Loss: 28.6520
# 3372.835205078125
# Mean Squared Error: 259.4488525390625

# %%
print('nn y_pred:', y_pred)
print('nn y_test:', y_test)

tmp = torch.arange(len(y_pred))
plt.plot(tmp, y_pred, label='y_pred')
plt.plot(tmp, y_test, label='y_test')
plt.legend()
plt.show()
# Out:
# nn y_pred: tensor([[27.6990],
#         [29.7508],
#         [34.9009],
#         [38.9803],
#         [44.8988],
#         [50.3327],
#         [59.3818],
#         [25.0994],
#         [26.5512],
#         [30.6596],
#         [36.6626],
#         [56.3452],
#         [64.6285]])
# nn y_test: tensor([[ 1.0040],
#         [ 9.0600],
#         [12.8400],
#         [23.3400],
#         [35.0280],
#         [37.7790],
#         [51.3700],
#         [ 7.0550],
#         [ 9.7560],
#         [13.6380],
#         [28.1170],
#         [43.0080],
#         [70.3960]])
